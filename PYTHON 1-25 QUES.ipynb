# %%
# Python program to find the largest of three numbers

num1=float(input('Enter first number:'))
num2=float(input('Enter second number:'))
num3=float(input('Enter third number:'))

if(num1>=num2) and (num1>=num3):
    largest=num1
elif(num2>=num1) and (num2>=num3):
    largest=num2
else:
    largest=num3
print('largest number=',largest)
# Out:
# Enter first number: 3
# Enter second number: 4
# Enter third number: 6
# largest number= 6.0

# %%
#python program to check whether no. is even or odd 
def odd_even():
    num = int(input('enter a number'))
    if (num % 2)==0:
        print('even number',num)
    else:
        print('odd number',num)
odd_even()
# Out:
# enter a number 3
# odd number 3

# %%
#program to accept string and reverse
def reverse_string(input_string):
    if len(input_string) == 0:
        return input_string
    else:
        return reverse_string(input_string[1:]) + input_string[0]

string = "Hello, World!"
reversed_string = reverse_string(string)
print(reversed_string)
# Out:
# !dlroW ,olleH

# %%
# Using dictionary and list comprehension

ip_str = 'Hello,my name is manya'
ip_str = ip_str.casefold()

# count the vowels
count = {x:sum([1 for char in ip_str if char == x]) for x in 'aeiou'}
print('',ip_str)
print(count)
# Out:
#  hello,my name is manya
# {'a': 3, 'e': 2, 'i': 1, 'o': 1, 'u': 0}

# %%
#calculator
num1 = float(input("Enter first number: "))
num2 = float(input("Enter second number: "))
operation = input("Choose operation (+, -, *, /): ")

if operation == "+":
    print("Result:", num1 + num2)
elif operation == "-":
    print("Result:", num1 - num2)
elif operation == "*":
    print("Result:", num1 * num2)
elif operation == "/":
    if num2 != 0:
        print("Result:", num1 / num2)
    else:
        print("Error: Division by zero!")
else:
    print("Invalid operation.")
# Out:
# Enter first number:  45
# Enter second number:  44
# Choose operation (+, -, *, /):  +
# Result: 89.0

# %%
# prime no
num = int(input("Enter a number: "))
if num > 1:
    for i in range(2, int(num**0.5) + 1):
        if num % i == 0:
            print(num, "is not a prime number")
            break
    else:
        print(num, "is a prime number")
else:
    print(num, "is not a prime number")
# Out:
# Enter a number:  45
# 45 is not a prime number

# %%
#multiplication of a number
def multiplication(num):
    num=int(input('Enter a number'))
    for i in range(1,11):
        print(f"{num} x {i} = {num * i}")
multiplication(num)
# Out:
# Enter a number 2
# 2 x 1 = 2
# 2 x 2 = 4
# 2 x 3 = 6
# 2 x 4 = 8
# 2 x 5 = 10
# 2 x 6 = 12
# 2 x 7 = 14
# 2 x 8 = 16
# 2 x 9 = 18
# 2 x 10 = 20

# %%
# Fibonacci series 
n = int(input("Enter number of terms: "))
a, b = 0, 1
for i in range(n):
    print(a, end=" ")
    a, b = b, a + b
# Out:
# Enter number of terms:  1
# 0

# %%
# factorial
num = int(input("Enter a number: "))
factorial = 1
for i in range(1, num + 1):
    factorial *= i
print("Factorial of", num, "is", factorial)
# Out:
# Enter a number:  3
# Factorial of 3 is 6

# %%
#palindrome
num = int(input("Enter a number: "))
original = str(num)
reversed_num = original[::-1]
if original == reversed_num:
    print(num, "is a palindrome")
else:
    print(num, "is not a palindrome")
# Out:
# Enter a number:  34556
# 34556 is not a palindrome

# %%
#sum of digit using while loop
num = int(input("Enter a first number: "))
num = int(input("Enter a second number: "))
sum_digits = 0
while num > 0:
    sum_digits += num % 10
    num //= 10
print("Sum of digits:", sum_digits)
# Out:
# Enter a first number:  45
# Enter a second number:  55
# Sum of digits: 10

# %%
#farenheit and celsius
celsius=int(input("Enter a temperature:"))
farenheit=(celsius * 9/5) + 32
print("Temperature in Fahrenheit:", farenheit)
# Out:
# Enter a temperature: 5
# Temperature in Fahrenheit: 41.0

# %%
def find_max(a, b):
    if a > b:
        return a
    else :
        return b

print(find_max(10, 20))
# Out:
# 20

# %%
#average of list 
nums = list(map(int, input("Enter numbers separated by space: ").split()))
average = sum(nums) / len(nums)
print("Average:", average)
# Out:
# Enter numbers separated by space:  3 4 5 6
# Average: 4.5

# %%
#second largest number in list 
nums = list(map(int, input("Enter numbers: ").split()))
unique_nums = list(set(nums))
unique_nums.sort()
if len(unique_nums) >= 2:
    print("Second largest:", unique_nums[-2])
else:
    print("Not enough unique numbers.")
# Out:
# Enter numbers:  3 4 5  6
# Second largest: 5

# %%
#count 
sentence=input("enter a sentence:")
words=sentence.split()
print("number of words",len(words))
# Out:
# enter a sentence: manya
# number of words 1

# %%
# duplicates
nums = list(map(int, input("Enter numbers: ").split()))
no_duplicates = list(set(nums))
print("List after removing duplicates:", no_duplicates)
# Out:
# Enter numbers:  3 3 5 6 3
# List after removing duplicates: [3, 5, 6]

# %%
#dictionary
keys = input("Enter keys separated by space: ").split()
values = input("Enter values separated by space: ").split()
dictionary = dict(zip(keys, values))
print("Created dictionary:", dictionary)
# Out:
# Enter keys separated by space:  name age
# Enter values separated by space:  manya 18
# Created dictionary: {'name': 'manya', 'age': '18'}

# %%
#sort
nums = list(map(int, input("Enter numbers: ").split()))
for i in range(len(nums)):
    for j in range(i+1, len(nums)):
        if nums[i] > nums[j]:
            nums[i], nums[j] = nums[j], nums[i]
print("Sorted list:", nums)
# Out:
# Enter numbers:  3 4 7 8 2 0
# Sorted list: [0, 2, 3, 4, 7, 8]

# %%
#pangram
import string
def is_pangram(sentence):
    alphabet = set(string.ascii_lowercase)
    return alphabet <= set(sentence.lower())

print(is_pangram("The quick brown fox jumps over the lazy dog"))
# Out:
# True

# %%
# number or not 
def is_number(value):
    try:
        float(value)
        return True
    except ValueError:
        return False

print(is_number("123"))  # True
print(is_number("abc"))  # False
# Out:
# True
# False

# %%
#angrams
def are_anagrams(str1, str2):
    return sorted(str1) == sorted(str2)

print(are_anagrams("listen", "silent"))  # True
# Out:
# True

# %%
# Binary, Octal, Hexadecimal of a number
num = int(input("Enter a number: "))
print("Binary:", bin(num))
print("Octal:", oct(num))
print("Hexadecimal:", hex(num))
# Out:
# Enter a number:  786
# Binary: 0b1100010010
# Octal: 0o1422
# Hexadecimal: 0x312

# %%
# greater than 50
nums = list(map(int, input("Enter numbers: ").split()))
greater_than_50 = [num for num in nums if num > 50]
print("Numbers greater than 50:", greater_than_50)
# Out:
# Enter numbers:  34 44 23 56 67 88 99
# Numbers greater than 50: [56, 67, 88, 99]

# %%
#count
def count_case(text):
    upper = sum(1 for c in text if c.isupper())
    lower = sum(1 for c in text if c.islower())
    return upper, lower

text = input("Enter a string: ")
u, l = count_case(text)
print("Uppercase:", u)
print("Lowercase:", l)
# Out:
# Enter a string:  MAnya
# Uppercase: 2
# Lowercase: 3
